# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv(r'C:\Users\jdrij\OneDrive\Bureaublad\Master\ML_Github\ML4QS-project\data\train_df.csv')
# test_df = pd.read_csv(r'C:\Users\jdrij\OneDrive\Bureaublad\Master\ML_Github\ML4QS-project\data\test_df.csv')

# %%
def split_train_val(df, n_groups=5, val_group=0):
    grouped = []

    for label in df['transport_mode'].unique():
        df_label = df[df['transport_mode'] == label].copy()
        df_label = df_label.sort_values(by='Time').reset_index(drop=True)  # <-- chronologische volgorde

        # Verdeel in ongeveer gelijke groepen
        split_groups = np.array_split(df_label, n_groups)
        for i, group in enumerate(split_groups):
            group['group'] = i
            grouped.append(group)

    df_grouped = pd.concat(grouped).reset_index(drop=True)

    val_set = df_grouped[df_grouped['group'] == val_group]
    train_set = df_grouped[df_grouped['group'] != val_group]

    return train_set.drop(columns=['group']), val_set.drop(columns=['group'])

# Voorbeeld gebruik:
train_df_hyper, val_df_hyper = split_train_val(train_df, val_group=0)
# Out:
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
train_df_hyper.shape
# Out:
# (3100, 95)

# %%
val_df_hyper.shape
# Out:
# (780, 95)

# %% [markdown]
# XGBoost

# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder

# -----------------------------
# Stap 1: Voorbereiden van data
# -----------------------------
X_train_xgb = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_xgb = train_df_hyper['transport_mode']

X_val_xgb = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_xgb = val_df_hyper['transport_mode']

# -----------------------------
# Stap 2: Encode labels
# -----------------------------
le_xgb = LabelEncoder()
y_train_enc_xgb = le_xgb.fit_transform(y_train_xgb)
y_val_enc_xgb = le_xgb.transform(y_val_xgb)

print("Label mapping (XGB):", dict(zip(le_xgb.classes_, le_xgb.transform(le_xgb.classes_))))

# -----------------------------
# Stap 3: Combineer train en val
# -----------------------------
X_combined_xgb = pd.concat([X_train_xgb, X_val_xgb], axis=0)
y_combined_xgb = np.concatenate([y_train_enc_xgb, y_val_enc_xgb])

val_fold_xgb = [-1] * len(X_train_xgb) + [0] * len(X_val_xgb)
ps_xgb = PredefinedSplit(val_fold_xgb)

# -----------------------------
# Stap 4: Hyperparameterraster
# -----------------------------
param_grid_xgb = {
    'n_estimators': [100, 200, 300, 400, 500, 700, 1000],
    'max_depth': [2, 3, 4, 5, 6, 7, 8, 9],
    'learning_rate': [0.01, 0.05, 0.1, 0.15, 0.2],
    'subsample': [0.5, 0.8, 1.0],
    'colsample_bytree': [0.5, 0.8, 1.0]
}

# -----------------------------
# Stap 5: Grid Search
# -----------------------------
model_xgb = XGBClassifier(
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

grid_search_xgb = GridSearchCV(
    estimator=model_xgb,
    param_grid=param_grid_xgb,
    scoring='accuracy',
    n_jobs=-1,
    cv=ps_xgb,
    verbose=2,
    return_train_score=True
)

grid_search_xgb.fit(X_combined_xgb, y_combined_xgb)

# -----------------------------
# Stap 6: Toon train en val scores
# -----------------------------
results_xgb = pd.DataFrame(grid_search_xgb.cv_results_)

print("\nTrain/Validation scores per parameter set (XGB):\n")
for i in range(len(results_xgb)):
    params = results_xgb.loc[i, 'params']
    train_acc = results_xgb.loc[i, 'mean_train_score']
    val_acc = results_xgb.loc[i, 'mean_test_score']
    print(f"Parameters: {params}")
    print(f"→ Train accuracy: {train_acc:.4f}, Val accuracy: {val_acc:.4f}\n")

# -----------------------------
# Beste combinatie + accuracies
# -----------------------------
print("Beste hyperparameters (XGB):")
print(grid_search_xgb.best_params_)

best_params_xgb = grid_search_xgb.best_params_
best_train_acc_xgb = results_xgb.loc[grid_search_xgb.best_index_, 'mean_train_score']
best_val_acc_xgb = results_xgb.loc[grid_search_xgb.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (XGB):")
print(best_params_xgb)
print(f"→ Train Accuracy:      {best_train_acc_xgb:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_xgb:.4f}")
# Out:
# Label mapping (XGB): {'auto': 0, 'fietsen': 1, 'metro': 2, 'rennen': 3, 'trein': 4}
# Fitting 1 folds for each of 1728 candidates, totalling 1728 fits
# c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\xgboost\training.py:183: UserWarning: [11:46:43] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Train/Validation scores per parameter set (XGB):
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9974
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9974
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9974
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9128
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8564
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8474
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8474
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8474
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9359
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8551
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8872
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9269
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8872
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9333
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9167
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8679
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9154
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9115
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9218
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8551
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9244
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8564
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9115
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8436
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8500
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8449
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8449
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8474
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8474
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9321
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9218
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9244
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9795
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9295
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9115
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9051
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9244
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8628
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9192
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8590
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9244
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8641
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8718
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9731
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9269
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8872
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9256
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9295
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9231
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.8859
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9244
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9141
#
# Parameters: {'colsample_bytree': 0.8, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# ...
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9756
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9833
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9641
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9705
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9641
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9423
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9346
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9487
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9833
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9782
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9744
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9641
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9705
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9641
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9769
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9423
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9346
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9487
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 0.1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9846
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 1, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 0.1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9808
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 1, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 0.8}
# → Train accuracy: 1.0000, Val accuracy: 0.9782
#
# Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 400, 'reg_alpha': 10, 'reg_lambda': 10, 'subsample': 1.0}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Beste hyperparameters (XGB):
# {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
#
# Beste hyperparameters (XGB):
# {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 10, 'subsample': 1.0}
# → Train Accuracy:      1.0000
# → Validation Accuracy: 1.0000

# %%
results_to_save = results_xgb[[
    'params',
    'mean_train_score',
    'mean_test_score',  # test = validation in GridSearchCV
    'rank_test_score'
]]

# Expand the 'params' dictionary into separate columns
params_df = results_xgb['params'].apply(pd.Series)

# Combine everything into one DataFrame
full_results_df = pd.concat([
    params_df,
    results_to_save.drop(columns=['params'])
], axis=1)

# Rename for clarity
full_results_df.rename(columns={
    'mean_train_score': 'train_accuracy',
    'mean_test_score': 'val_accuracy'
}, inplace=True)

# Save to CSV
full_results_df.to_csv("xgb_train_val_accuracy_results.csv", index=False)

print("Train and validation accuracy results saved to 'xgb_train_val_accuracy_results.csv'")
# Out:
# Train and validation accuracy results saved to 'xgb_train_val_accuracy_results.csv'

# %% [markdown]
# Randomforest

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder

# -----------------------------
# Stap 1: Voorbereiden van data
# -----------------------------
X_train_rf = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_rf = train_df_hyper['transport_mode']

X_val_rf = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_rf = val_df_hyper['transport_mode']

# -----------------------------
# Stap 2: Encode labels
# -----------------------------
le_rf = LabelEncoder()
y_train_enc_rf = le_rf.fit_transform(y_train_rf)
y_val_enc_rf = le_rf.transform(y_val_rf)

print("Label mapping (RF):", dict(zip(le_rf.classes_, le_rf.transform(le_rf.classes_))))

# -----------------------------
# Stap 3: Combineer train en val
# -----------------------------
X_combined_rf = pd.concat([X_train_rf, X_val_rf], axis=0)
y_combined_rf = np.concatenate([y_train_enc_rf, y_val_enc_rf])

val_fold_rf = [-1] * len(X_train_rf) + [0] * len(X_val_rf)
ps_rf = PredefinedSplit(val_fold_rf)

# -----------------------------
# Stap 4: Hyperparameterraster
# -----------------------------
param_grid_rf = {
    'n_estimators': [100, 200, 300, 500, 700, 1000],
    'max_depth': [None,5, 10, 20, 50],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 8],
    'max_features': ['auto', 'sqrt', 'log2', 0.2, 0.5, 0.8],
    'bootstrap': [True, False],
    'class_weight': [None, 'balanced', 'balanced_subsample']
}

# -----------------------------
# Stap 5: Grid Search
# -----------------------------
model_rf = RandomForestClassifier(random_state=42)

grid_search_rf = GridSearchCV(
    estimator=model_rf,
    param_grid=param_grid_rf,
    scoring='accuracy',
    n_jobs=-1,
    cv=ps_rf,
    verbose=2,
    return_train_score=True
)

grid_search_rf.fit(X_combined_rf, y_combined_rf)

# -----------------------------
# Stap 6: Resultaten tonen
# -----------------------------
results_rf = pd.DataFrame(grid_search_rf.cv_results_)

print("\nTrain/Validation scores per parameter set (RF):\n")
for i in range(len(results_rf)):
    params = results_rf.loc[i, 'params']
    train_acc = results_rf.loc[i, 'mean_train_score']
    val_acc = results_rf.loc[i, 'mean_test_score']
    print(f"Parameters: {params}")
    print(f"→ Train accuracy: {train_acc:.4f}, Val accuracy: {val_acc:.4f}\n")

# -----------------------------
# Beste combinatie + accuracies
# -----------------------------
print("Beste hyperparameters (RF):")
print(grid_search_rf.best_params_)

best_params_rf = grid_search_rf.best_params_
best_train_acc_rf = results_rf.loc[grid_search_rf.best_index_, 'mean_train_score']
best_val_acc_rf = results_rf.loc[grid_search_rf.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (Random Forest):")
print(best_params_rf)
print(f"→ Train Accuracy:      {best_train_acc_rf:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_rf:.4f}")
# Out:
# Label mapping (RF): {'auto': 0, 'fietsen': 1, 'metro': 2, 'rennen': 3, 'trein': 4}
# Fitting 1 folds for each of 72 candidates, totalling 72 fits
#
# Train/Validation scores per parameter set (RF):
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9897
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9897
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9897
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9910
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# → Train accuracy: 1.0000, Val accuracy: 0.9859
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# → Train accuracy: 1.0000, Val accuracy: 0.9872
#
# Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300}
# → Train accuracy: 1.0000, Val accuracy: 0.9885
#
# Beste hyperparameters (RF):
# {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
#
# Beste hyperparameters (Random Forest):
# {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# → Train Accuracy:      1.0000
# → Validation Accuracy: 0.9910

# %% [markdown]
# Catboost

# %%
import pandas as pd
import numpy as np
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder

# -----------------------------
# Stap 1: Voorbereiden van data
# -----------------------------
X_train_cb = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_cb = train_df_hyper['transport_mode']

X_val_cb = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_cb = val_df_hyper['transport_mode']

# -----------------------------
# Stap 2: Encode labels
# -----------------------------
le_cb = LabelEncoder()
y_train_enc_cb = le_cb.fit_transform(y_train_cb)
y_val_enc_cb = le_cb.transform(y_val_cb)

print("Label mapping (CatBoost):", dict(zip(le_cb.classes_, le_cb.transform(le_cb.classes_))))

# -----------------------------
# Stap 3: Combineer train en val
# -----------------------------
X_combined_cb = pd.concat([X_train_cb, X_val_cb], axis=0)
y_combined_cb = np.concatenate([y_train_enc_cb, y_val_enc_cb])

val_fold_cb = [-1] * len(X_train_cb) + [0] * len(X_val_cb)
ps_cb = PredefinedSplit(val_fold_cb)

# -----------------------------
# Stap 4: Hyperparameterraster
# -----------------------------
param_grid_cb = {
    'iterations': [200, 300],
    'learning_rate': [0.05, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3]
}

# -----------------------------
# Stap 5: Grid Search
# -----------------------------
model_cb = CatBoostClassifier(
    verbose=0,
    random_state=42,
    loss_function='MultiClass'
)

grid_search_cb = GridSearchCV(
    estimator=model_cb,
    param_grid=param_grid_cb,
    scoring='accuracy',
    cv=ps_cb,
    n_jobs=-1,
    verbose=2,
    return_train_score=True
)

grid_search_cb.fit(X_combined_cb, y_combined_cb)

# -----------------------------
# Stap 6: Resultaten tonen
# -----------------------------
results_cb = pd.DataFrame(grid_search_cb.cv_results_)

print("\nTrain/Validation scores per parameter set (CatBoost):\n")
for i in range(len(results_cb)):
    params = results_cb.loc[i, 'params']
    train_acc = results_cb.loc[i, 'mean_train_score']
    val_acc = results_cb.loc[i, 'mean_test_score']
    print(f"Parameters: {params}")
    print(f"→ Train accuracy: {train_acc:.4f}, Val accuracy: {val_acc:.4f}\n")

# -----------------------------
# Beste combinatie + accuracies
# -----------------------------
print("Beste hyperparameters (CatBoost):")
print(grid_search_cb.best_params_)

best_params_cb = grid_search_cb.best_params_
best_train_acc_cb = results_cb.loc[grid_search_cb.best_index_, 'mean_train_score']
best_val_acc_cb = results_cb.loc[grid_search_cb.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (CatBoost):")
print(best_params_cb)
print(f"→ Train Accuracy:      {best_train_acc_cb:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_cb:.4f}")
# Out:
# Label mapping (CatBoost): {'auto': 0, 'fietsen': 1, 'metro': 2, 'rennen': 3, 'trein': 4}
# Fitting 1 folds for each of 24 candidates, totalling 24 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 63
#      47 model_cb = CatBoostClassifier(
#      48     verbose=0,
#      49     random_state=42,
#      50     loss_function='MultiClass'
#      51 )
#      53 grid_search_cb = GridSearchCV(
#      54     estimator=model_cb,
#      55     param_grid=param_grid_cb,
#    (...)
#      60     return_train_score=True
#      61 )
# ---> 63 grid_search_cb.fit(X_combined_cb, y_combined_cb)
#      65 # -----------------------------
#      66 # Stap 6: Resultaten tonen
#      67 # -----------------------------
#      68 results_cb = pd.DataFrame(grid_search_cb.cv_results_)
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\sklearn\model_selection\_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\sklearn\model_selection\_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\sklearn\model_selection\_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\sklearn\utils\parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\joblib\parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\joblib\parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File c:\Users\jdrij\anaconda3\envs\condaenv\lib\site-packages\joblib\parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import pandas as pd

# -----------------------------
# Prepare data
# -----------------------------
X_train_knn = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_knn = train_df_hyper['transport_mode']

X_val_knn = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_knn = val_df_hyper['transport_mode']

# Encode labels
le_knn = LabelEncoder()
y_train_enc_knn = le_knn.fit_transform(y_train_knn)
y_val_enc_knn = le_knn.transform(y_val_knn)

# Combine and scale
X_combined_knn = pd.concat([X_train_knn, X_val_knn], axis=0)
y_combined_knn = np.concatenate([y_train_enc_knn, y_val_enc_knn])

scaler_knn = StandardScaler()
X_combined_knn_scaled = scaler_knn.fit_transform(X_combined_knn)

# Predefined split
val_fold_knn = [-1] * len(X_train_knn) + [0] * len(X_val_knn)
ps_knn = PredefinedSplit(val_fold_knn)

# -----------------------------
# Define hyperparameter grid
# -----------------------------
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]  # Manhattan and Euclidean
}

# -----------------------------
# Grid Search
# -----------------------------
model_knn = KNeighborsClassifier()
grid_search_knn = GridSearchCV(
    estimator=model_knn,
    param_grid=param_grid_knn,
    scoring='accuracy',
    n_jobs=-1,
    cv=ps_knn,
    verbose=2,
    return_train_score=True
)

grid_search_knn.fit(X_combined_knn_scaled, y_combined_knn)

# -----------------------------
# Results
# -----------------------------
results_knn = pd.DataFrame(grid_search_knn.cv_results_)

# Best parameters + accuracies
best_params_knn = grid_search_knn.best_params_
best_train_acc_knn = results_knn.loc[grid_search_knn.best_index_, 'mean_train_score']
best_val_acc_knn = results_knn.loc[grid_search_knn.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (KNN):")
print(best_params_knn)
print(f"→ Train Accuracy:      {best_train_acc_knn:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_knn:.4f}")

# %% [markdown]
# Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
import pandas as pd

# -----------------------------
# Prepare data
# -----------------------------
X_train_logreg = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_logreg = train_df_hyper['transport_mode']

X_val_logreg = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_logreg = val_df_hyper['transport_mode']

# Encode target
le_logreg = LabelEncoder()
y_train_enc_logreg = le_logreg.fit_transform(y_train_logreg)
y_val_enc_logreg = le_logreg.transform(y_val_logreg)

# Combine train and val
X_combined_logreg = pd.concat([X_train_logreg, X_val_logreg], axis=0)
y_combined_logreg = np.concatenate([y_train_enc_logreg, y_val_enc_logreg])

# Scaling
scaler_logreg = StandardScaler()
X_combined_scaled_logreg = scaler_logreg.fit_transform(X_combined_logreg)

# Predefined split
val_fold_logreg = [-1] * len(X_train_logreg) + [0] * len(X_val_logreg)
ps_logreg = PredefinedSplit(val_fold_logreg)

# -----------------------------
# Define hyperparameter grid
# -----------------------------
param_grid_logreg = {
    'penalty': ['l2'],
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['lbfgs'],
    'max_iter': [500, 1000]
}

# -----------------------------
# Grid Search
# -----------------------------
model_logreg = LogisticRegression()
grid_search_logreg = GridSearchCV(
    estimator=model_logreg,
    param_grid=param_grid_logreg,
    scoring='accuracy',
    n_jobs=-1,
    cv=ps_logreg,
    verbose=2,
    return_train_score=True
)

grid_search_logreg.fit(X_combined_scaled_logreg, y_combined_logreg)

# -----------------------------
# Results
# -----------------------------
results_logreg = pd.DataFrame(grid_search_logreg.cv_results_)

# Best parameters + train/val accuracy
best_params_logreg = grid_search_logreg.best_params_
best_train_acc_logreg = results_logreg.loc[grid_search_logreg.best_index_, 'mean_train_score']
best_val_acc_logreg = results_logreg.loc[grid_search_logreg.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (Logistic Regression):")
print(best_params_logreg)
print(f"→ Train Accuracy:      {best_train_acc_logreg:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_logreg:.4f}")

# %% [markdown]
# Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, PredefinedSplit
from sklearn.preprocessing import LabelEncoder
import numpy as np
import pandas as pd

# -----------------------------
# Step 1: Prepare data
# -----------------------------
X_train_dt = train_df_hyper.drop(columns=['transport_mode', 'Time'])
y_train_dt = train_df_hyper['transport_mode']

X_val_dt = val_df_hyper.drop(columns=['transport_mode', 'Time'])
y_val_dt = val_df_hyper['transport_mode']

# Encode labels
le_dt = LabelEncoder()
y_train_enc_dt = le_dt.fit_transform(y_train_dt)
y_val_enc_dt = le_dt.transform(y_val_dt)

# Combine data
X_combined_dt = pd.concat([X_train_dt, X_val_dt], axis=0)
y_combined_dt = np.concatenate([y_train_enc_dt, y_val_enc_dt])

val_fold_dt = [-1] * len(X_train_dt) + [0] * len(X_val_dt)
ps_dt = PredefinedSplit(val_fold_dt)

# -----------------------------
# Step 2: Define hyperparameter grid
# -----------------------------
param_grid_dt = {
    'max_depth': [None, 5, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# -----------------------------
# Step 3: Grid Search
# -----------------------------
model_dt = DecisionTreeClassifier(random_state=42)

grid_search_dt = GridSearchCV(
    estimator=model_dt,
    param_grid=param_grid_dt,
    scoring='accuracy',
    n_jobs=-1,
    cv=ps_dt,
    verbose=2,
    return_train_score=True
)

grid_search_dt.fit(X_combined_dt, y_combined_dt)

# -----------------------------
# Step 4: Results
# -----------------------------
results_dt = pd.DataFrame(grid_search_dt.cv_results_)

# Best parameters + accuracies
best_params_dt = grid_search_dt.best_params_
best_train_acc_dt = results_dt.loc[grid_search_dt.best_index_, 'mean_train_score']
best_val_acc_dt = results_dt.loc[grid_search_dt.best_index_, 'mean_test_score']

print("\nBeste hyperparameters (Decision Tree):")
print(best_params_dt)
print(f"→ Train Accuracy:      {best_train_acc_dt:.4f}")
print(f"→ Validation Accuracy: {best_val_acc_dt:.4f}")
